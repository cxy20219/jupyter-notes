# %%
import numpy as np
# 创建一个符合正态分布的10个股票5天的涨跌幅数据
stock_change = np.random.normal(0, 1, (10, 5))

# %%
stock_change
# Out:
# array([[-0.4235822 , -1.00914765,  0.19793852, -1.671841  , -0.03285001],
#        [ 0.53744951, -0.50741412,  1.1389422 , -0.03474965,  0.88765429],
#        [ 1.06808878,  1.72086947,  1.00589291, -0.86757645, -0.4271639 ],
#        [ 0.24631696,  0.39390223,  0.89987088,  0.16242146,  0.1520899 ],
#        [-0.91016718,  0.05133718, -0.45457137, -0.38760637,  0.26266849],
#        [ 1.5391462 ,  0.34460471,  1.40188407,  1.38169537, -1.41453788],
#        [-0.24109375,  0.84652901,  0.57812542, -1.10018823, -0.23481039],
#        [ 0.22582928,  0.43658869, -0.69457808,  0.68073023,  0.12469287],
#        [-0.02620502,  0.95845503,  0.76420182, -1.07014135,  1.49495084],
#        [ 1.01326259, -0.17823403, -0.89073912, -0.38782819,  0.17865138]])

# %%
import pandas as pd

# %% [markdown]
# ### 1.1 DataFrame

# %%
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4
# 0 -0.423582 -1.009148  0.197939 -1.671841 -0.032850
# 1  0.537450 -0.507414  1.138942 -0.034750  0.887654
# 2  1.068089  1.720869  1.005893 -0.867576 -0.427164
# 3  0.246317  0.393902  0.899871  0.162421  0.152090
# 4 -0.910167  0.051337 -0.454571 -0.387606  0.262668
# 5  1.539146  0.344605  1.401884  1.381695 -1.414538
# 6 -0.241094  0.846529  0.578125 -1.100188 -0.234810
# 7  0.225829  0.436589 -0.694578  0.680730  0.124693
# 8 -0.026205  0.958455  0.764202 -1.070141  1.494951
# 9  1.013263 -0.178234 -0.890739 -0.387828  0.178651

# %%
# 添加行索引
stock = ["股票{}".format(i) for i in range(10)]

# %%
pd.DataFrame(stock_change, index=stock)
# Out:
#             0         1         2         3         4
# 股票0 -0.423582 -1.009148  0.197939 -1.671841 -0.032850
# 股票1  0.537450 -0.507414  1.138942 -0.034750  0.887654
# 股票2  1.068089  1.720869  1.005893 -0.867576 -0.427164
# 股票3  0.246317  0.393902  0.899871  0.162421  0.152090
# 股票4 -0.910167  0.051337 -0.454571 -0.387606  0.262668
# 股票5  1.539146  0.344605  1.401884  1.381695 -1.414538
# 股票6 -0.241094  0.846529  0.578125 -1.100188 -0.234810
# 股票7  0.225829  0.436589 -0.694578  0.680730  0.124693
# 股票8 -0.026205  0.958455  0.764202 -1.070141  1.494951
# 股票9  1.013263 -0.178234 -0.890739 -0.387828  0.178651

# %%
# 添加列索引
date = pd.date_range(start="20180101", periods=5, freq="B")

# %%
date
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
data = pd.DataFrame(stock_change, index=stock, columns=date)

# %%
data
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票2    1.068089    1.720869    1.005893   -0.867576   -0.427164
# 股票3    0.246317    0.393902    0.899871    0.162421    0.152090
# 股票4   -0.910167    0.051337   -0.454571   -0.387606    0.262668
# 股票5    1.539146    0.344605    1.401884    1.381695   -1.414538
# 股票6   -0.241094    0.846529    0.578125   -1.100188   -0.234810
# 股票7    0.225829    0.436589   -0.694578    0.680730    0.124693
# 股票8   -0.026205    0.958455    0.764202   -1.070141    1.494951
# 股票9    1.013263   -0.178234   -0.890739   -0.387828    0.178651

# %% [markdown]
# ### 1.2 DataFrame的属性

# %%
data # shape (10, 5)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票2    1.068089    1.720869    1.005893   -0.867576   -0.427164
# 股票3    0.246317    0.393902    0.899871    0.162421    0.152090
# 股票4   -0.910167    0.051337   -0.454571   -0.387606    0.262668
# 股票5    1.539146    0.344605    1.401884    1.381695   -1.414538
# 股票6   -0.241094    0.846529    0.578125   -1.100188   -0.234810
# 股票7    0.225829    0.436589   -0.694578    0.680730    0.124693
# 股票8   -0.026205    0.958455    0.764202   -1.070141    1.494951
# 股票9    1.013263   -0.178234   -0.890739   -0.387828    0.178651

# %%
data.shape
# Out:
# (10, 5)

# %%
data.index
# Out:
# Index(['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9'], dtype='object')

# %%
data.columns
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.values
# Out:
# array([[-0.4235822 , -1.00914765,  0.19793852, -1.671841  , -0.03285001],
#        [ 0.53744951, -0.50741412,  1.1389422 , -0.03474965,  0.88765429],
#        [ 1.06808878,  1.72086947,  1.00589291, -0.86757645, -0.4271639 ],
#        [ 0.24631696,  0.39390223,  0.89987088,  0.16242146,  0.1520899 ],
#        [-0.91016718,  0.05133718, -0.45457137, -0.38760637,  0.26266849],
#        [ 1.5391462 ,  0.34460471,  1.40188407,  1.38169537, -1.41453788],
#        [-0.24109375,  0.84652901,  0.57812542, -1.10018823, -0.23481039],
#        [ 0.22582928,  0.43658869, -0.69457808,  0.68073023,  0.12469287],
#        [-0.02620502,  0.95845503,  0.76420182, -1.07014135,  1.49495084],
#        [ 1.01326259, -0.17823403, -0.89073912, -0.38782819,  0.17865138]])

# %%
data.T
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2018-01-01 -0.423582  0.537450  1.068089  0.246317 -0.910167  1.539146
# 2018-01-02 -1.009148 -0.507414  1.720869  0.393902  0.051337  0.344605
# 2018-01-03  0.197939  1.138942  1.005893  0.899871 -0.454571  1.401884
# 2018-01-04 -1.671841 -0.034750 -0.867576  0.162421 -0.387606  1.381695
# 2018-01-05 -0.032850  0.887654 -0.427164  0.152090  0.262668 -1.414538
#
#                  股票6       股票7       股票8       股票9
# 2018-01-01 -0.241094  0.225829 -0.026205  1.013263
# 2018-01-02  0.846529  0.436589  0.958455 -0.178234
# 2018-01-03  0.578125 -0.694578  0.764202 -0.890739
# 2018-01-04 -1.100188  0.680730 -1.070141 -0.387828
# 2018-01-05 -0.234810  0.124693  1.494951  0.178651

# %%
data.head(3)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票2    1.068089    1.720869    1.005893   -0.867576   -0.427164

# %%
data.tail(2)
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票8   -0.026205    0.958455    0.764202   -1.070141    1.494951
# 股票9    1.013263   -0.178234   -0.890739   -0.387828    0.178651

# %% [markdown]
# ### 2.1 修改行列索引值

# %%
data.head()
# Out:
#      2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票2    1.068089    1.720869    1.005893   -0.867576   -0.427164
# 股票3    0.246317    0.393902    0.899871    0.162421    0.152090
# 股票4   -0.910167    0.051337   -0.454571   -0.387606    0.262668

# %%
# data.index[2] = "股票88"     # 不能单独修改索引

# %%
stock_ = ["股票_{}".format(i) for i in range(10)]

# %%
data.index = stock_

# %%
data.index
# Out:
# Index(['股票_0', '股票_1', '股票_2', '股票_3', '股票_4', '股票_5', '股票_6', '股票_7', '股票_8',
#        '股票_9'],
#       dtype='object')

# %%
data
# Out:
#       2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票_0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票_1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票_2    1.068089    1.720869    1.005893   -0.867576   -0.427164
# 股票_3    0.246317    0.393902    0.899871    0.162421    0.152090
# 股票_4   -0.910167    0.051337   -0.454571   -0.387606    0.262668
# 股票_5    1.539146    0.344605    1.401884    1.381695   -1.414538
# 股票_6   -0.241094    0.846529    0.578125   -1.100188   -0.234810
# 股票_7    0.225829    0.436589   -0.694578    0.680730    0.124693
# 股票_8   -0.026205    0.958455    0.764202   -1.070141    1.494951
# 股票_9    1.013263   -0.178234   -0.890739   -0.387828    0.178651

# %% [markdown]
# ### 2.2 重设索引

# %%
data.reset_index(drop=False)
# Out:
#   index  2018-01-01 00:00:00  2018-01-02 00:00:00  2018-01-03 00:00:00  \
# 0  股票_0            -0.423582            -1.009148             0.197939
# 1  股票_1             0.537450            -0.507414             1.138942
# 2  股票_2             1.068089             1.720869             1.005893
# 3  股票_3             0.246317             0.393902             0.899871
# 4  股票_4            -0.910167             0.051337            -0.454571
# 5  股票_5             1.539146             0.344605             1.401884
# 6  股票_6            -0.241094             0.846529             0.578125
# 7  股票_7             0.225829             0.436589            -0.694578
# 8  股票_8            -0.026205             0.958455             0.764202
# 9  股票_9             1.013263            -0.178234            -0.890739
#
#    2018-01-04 00:00:00  2018-01-05 00:00:00
# 0            -1.671841            -0.032850
# 1            -0.034750             0.887654
# 2            -0.867576            -0.427164
# ...

# %% [markdown]
# ### 2.3 设置新索引

# %%
df = pd.DataFrame({'month': [1, 4, 7, 10],
                    'year': [2012, 2014, 2013, 2014],
                    'sale':[55, 40, 84, 31]})

# %%
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
# 以月份设置新的索引
df.set_index("month", drop=False)
# Out:
#        month  year  sale
# month
# 1          1  2012    55
# 4          4  2014    40
# 7          7  2013    84
# 10        10  2014    31

# %%
# 以月份设置新的索引
df.set_index("month", drop=True)
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
# 设置多个索引，以年和月份
new_df = df.set_index(["year", "month"])

# %%
new_df
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
new_df.index
# Out:
# MultiIndex([(2012,  1),
#             (2014,  4),
#             (2013,  7),
#             (2014, 10)],
#            names=['year', 'month'])

# %% [markdown]
# ### 3.1 MultiIndex属性

# %%
new_df.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
new_df.index.levels
# Out:
# FrozenList([[2012, 2013, 2014], [1, 4, 7, 10]])

# %% [markdown]
# ### 3.2 Panel(新版本已经删除 推荐使用MultiIndex)
#
# 存储三维数据

# %%
# p = pd.Panel(np.arange(24).reshape(4,3,2),
#                  items=list('ABCD'),                             # 维度1
#                  major_axis=pd.date_range('20130101', periods=3),# 维度2
#                  minor_axis=['first', 'second'])                 # 维度3

# %%
# p

# %%
# p["A"]

# %%
# p["D"]

# %%
# p.major_xs("2013-01-01")

# %%
# p.minor_xs("first")

# %% [markdown]
# ### 3.3 Series

# %%
data
# Out:
#       2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05
# 股票_0   -0.423582   -1.009148    0.197939   -1.671841   -0.032850
# 股票_1    0.537450   -0.507414    1.138942   -0.034750    0.887654
# 股票_2    1.068089    1.720869    1.005893   -0.867576   -0.427164
# 股票_3    0.246317    0.393902    0.899871    0.162421    0.152090
# 股票_4   -0.910167    0.051337   -0.454571   -0.387606    0.262668
# 股票_5    1.539146    0.344605    1.401884    1.381695   -1.414538
# 股票_6   -0.241094    0.846529    0.578125   -1.100188   -0.234810
# 股票_7    0.225829    0.436589   -0.694578    0.680730    0.124693
# 股票_8   -0.026205    0.958455    0.764202   -1.070141    1.494951
# 股票_9    1.013263   -0.178234   -0.890739   -0.387828    0.178651

# %%
sr = data.iloc[1, :]

# %%
sr       # 带索引的一维数组
# Out:
# 2018-01-01    0.537450
# 2018-01-02   -0.507414
# 2018-01-03    1.138942
# 2018-01-04   -0.034750
# 2018-01-05    0.887654
# Freq: B, Name: 股票_1, dtype: float64

# %%
sr.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
sr.values
# Out:
# array([ 0.53744951, -0.50741412,  1.1389422 , -0.03474965,  0.88765429])

# %%
type(sr.values)
# Out:
# numpy.ndarray

# %%
pd.Series(np.arange(3, 9, 2), index=["a", "b", "c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int32

# %%
pd.Series({'red':100, 'blue':200, 'green': 500, 'yellow':1000})
# Out:
# red        100
# blue       200
# green      500
# yellow    1000
# dtype: int64

# %% [markdown]
# ### 4.1 基本数据操作

# %%
data = pd.read_csv("./stock_day/stock_day.csv")

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1) # 沿着第二个轴去操作

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# ...

# %%
stock_change
# Out:
# array([[-0.4235822 , -1.00914765,  0.19793852, -1.671841  , -0.03285001],
#        [ 0.53744951, -0.50741412,  1.1389422 , -0.03474965,  0.88765429],
#        [ 1.06808878,  1.72086947,  1.00589291, -0.86757645, -0.4271639 ],
#        [ 0.24631696,  0.39390223,  0.89987088,  0.16242146,  0.1520899 ],
#        [-0.91016718,  0.05133718, -0.45457137, -0.38760637,  0.26266849],
#        [ 1.5391462 ,  0.34460471,  1.40188407,  1.38169537, -1.41453788],
#        [-0.24109375,  0.84652901,  0.57812542, -1.10018823, -0.23481039],
#        [ 0.22582928,  0.43658869, -0.69457808,  0.68073023,  0.12469287],
#        [-0.02620502,  0.95845503,  0.76420182, -1.07014135,  1.49495084],
#        [ 1.01326259, -0.17823403, -0.89073912, -0.38782819,  0.17865138]])

# %%
stock_change[1, 1]
# Out:
# -0.5074141223848183

# %%
# data[1, 0] 不能直接进行数字索引

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data["open"]["2018-02-26"]
# Out:
# 22.8

# %%
# data["2018-02-26"]["open"] 必须先列后行

# %%
data.loc["2018-02-26"]["open"]
# Out:
# 22.8

# %%
data.loc["2018-02-26", "open"]
# Out:
# 22.8

# %%
data.iloc[1, 0]
# Out:
# 22.8

# %%
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
# data.ix[:4, ['open', 'close', 'high', 'low']]   pandas版本0.20.0及其以后版本中，ix已经不被推荐使用 用loc iloc 替换
data.loc[["2018-02-27","2018-02-26","2018-02-23","2018-02-22"], ['open', 'close', 'high', 'low']]
# Out:
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %% [markdown]
# ### 4.2 赋值操作

# %%
data.open = 100

# %%
data.iloc[1, 0] = 222

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %% [markdown]
# ### 4.3 排序

# %%
# 按内容进行排序
data.sort_values(by=["high", "p_change"], ascending=False).head() # 先high 如果相同再按p_change排序 False降序
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10   100  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12   100  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31   100  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15   100  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11   100  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %%
# 按索引进行排序
data.sort_index().head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# 2015-03-04      2.30
# 2015-03-05      3.19
# 2015-03-06      6.16

# %%
sr = data["price_change"]

# %%
sr
# Out:
# 2018-02-27    0.63
# 2018-02-26    0.69
# 2018-02-23    0.54
# 2018-02-22    0.36
# 2018-02-14    0.44
#               ...
# 2015-03-06    1.12
# 2015-03-05    0.26
# 2015-03-04    0.20
# 2015-03-03    0.18
# 2015-03-02    0.32
# Name: price_change, Length: 643, dtype: float64

# %%
sr.sort_values(ascending=False).head()   # False降序
# Out:
# 2015-06-09    3.03
# 2017-10-26    2.68
# 2015-05-21    2.57
# 2017-10-31    2.38
# 2017-06-22    2.36
# Name: price_change, dtype: float64

# %%
sr.sort_index().head()
# Out:
# 2015-03-02    0.32
# 2015-03-03    0.18
# 2015-03-04    0.20
# 2015-03-05    0.26
# 2015-03-06    1.12
# Name: price_change, dtype: float64

# %% [markdown]
# ### 5.1 算术运算

# %%
data["open"].add(3).head()
# Out:
# 2018-02-27    103
# 2018-02-26    225
# 2018-02-23    103
# 2018-02-22    103
# 2018-02-14    103
# Name: open, dtype: int64

# %%
data.sub(100).head()  # 等于data-100
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27     0 -74.12 -75.84 -76.47  95478.03        -99.37    -97.32
# 2018-02-26   122 -76.22 -76.47 -77.20  60885.11        -99.31    -96.98
# 2018-02-23     0 -76.63 -77.18 -77.29  52814.01        -99.46    -97.58
# 2018-02-22     0 -77.24 -77.72 -77.98  36005.01        -99.64    -98.36
# 2018-02-14     0 -78.01 -78.08 -78.52  23231.04        -99.56    -97.95
#
#             turnover
# 2018-02-27    -97.61
# 2018-02-26    -98.47
# 2018-02-23    -98.68
# 2018-02-22    -99.10
# 2018-02-14    -99.42

# %%
data["close"].sub(data["open"]).head()
# Out:
# 2018-02-27    -75.84
# 2018-02-26   -198.47
# 2018-02-23    -77.18
# 2018-02-22    -77.72
# 2018-02-14    -78.08
# dtype: float64

# %% [markdown]
# ### 5.2 逻辑运算符号<、 >、|、 &

# %%
# 例如筛选p_change > 2的日期数据
data[data["p_change"] > 2].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 完成一个多个逻辑判断， 筛选p_change > 2并且low > 15
data[(data["p_change"] > 2) & (data["low"] > 15)].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
data.query("p_change > 2 & low > 15").head()   # 多逻辑判断
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 判断'turnover'是否为4.19, 2.39
data[data["turnover"].isin([4.19, 2.39])]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2017-07-25   100  24.20  23.70  22.64  167489.48          0.67      2.91
# 2016-09-28   100  20.98  20.86  19.71   95580.75          0.98      4.93
# 2015-04-07   100  17.98  17.54  16.50  122471.85          0.88      5.28
#
#             turnover
# 2018-02-27      2.39
# 2017-07-25      4.19
# 2016-09-28      2.39
# 2015-04-07      4.19

# %% [markdown]
# ### 5.3 统计运算

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean   100.189736   21.900513   21.336267   20.771835   99905.519114
# std      4.811210    4.077578    3.942806    3.791968   73879.119354
# min    100.000000   12.670000   12.360000   12.200000    1158.120000
# 25%    100.000000   19.500000   19.045000   18.525000   48533.210000
# 50%    100.000000   21.970000   21.450000   20.980000   83175.930000
# 75%    100.000000   24.065000   23.415000   22.850000  127580.055000
# max    222.000000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change    turnover
# count    643.000000  643.000000  643.000000
# mean       0.018802    0.190280    2.936190
# std        0.898476    4.079698    2.079375
# min       -3.520000  -10.030000    0.040000
# 25%       -0.390000   -1.850000    1.360000
# 50%        0.050000    0.260000    2.500000
# ...

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data.max(axis=0)
# Out:
# open               222.00
# high                36.35
# close               35.21
# low                 34.01
# volume          501915.41
# price_change         3.03
# p_change            10.03
# turnover            12.56
# dtype: float64

# %%
data.idxmax(axis=0)
# Out:
# open            2018-02-26
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %% [markdown]
# ### 5.4 累计统计函数

# %%
 data["p_change"].sort_index().cumsum().plot()   # cumsum 累加
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5.5 自定义运算

# %%
data.apply(lambda x: x.max() - x.min())  # 默认asis=0 按列运算
# Out:
# open               122.00
# high                23.68
# close               22.85
# low                 21.81
# volume          500757.29
# price_change         6.55
# p_change            20.06
# turnover            12.52
# dtype: float64

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data["volume"].max() - data["volume"].min()
# Out:
# 500757.29

# %%
data.plot(x="volume", y="turnover", kind="scatter")
# Out:
# <AxesSubplot:xlabel='volume', ylabel='turnover'>

# %%
data.plot(x="high", y="low", kind="scatter")
# Out:
# <AxesSubplot:xlabel='high', ylabel='low'>

# %% [markdown]
# ### 6.1 读取csv文件-read_csv()

# %%
pd.read_csv("./stock_day/stock_day.csv", usecols=["high", "low", "open", "close"]).head()
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48

# %%
# stock_day2.csv 没有字段 会以数据作为索引 ，可以读取时添加索引名字
data = pd.read_csv("stock_day2.csv", names=["open", "high", "close", "low", "volume", "price_change", "p_change", "ma5", "ma10", "ma20", "v_ma5", "v_ma10", "v_ma20", "turnover"])

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
# 保存'open'列的数据
data[:10].to_csv("test.csv", columns=["open"])

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0   open
# 0  2018-02-27  23.53
# 1  2018-02-26  22.80
# 2  2018-02-23  22.88
# 3  2018-02-22  22.25
# 4  2018-02-14  21.49
# 5  2018-02-13  21.40
# 6  2018-02-12  20.70
# 7  2018-02-09  21.20
# 8  2018-02-08  21.79
# 9  2018-02-07  22.69

# %%
# mode a 追加, w 写入  不要行列索引
data[:10].to_csv("test.csv", columns=["open"], index=False, mode="w", header=False)

# %%
pd.read_csv("test.csv").head()
# Out:
#    23.53
# 0  22.80
# 1  22.88
# 2  22.25
# 3  21.49
# 4  21.40

# %% [markdown]
# ### 6.2 HDF5
#
# 读取和存储需要一个键

# %%
day_close = pd.read_hdf("./stock_data/day/day_close.h5")

# %%
day_close.head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %%
# 数据写入键 close
day_close.to_hdf("test.h5", key="close")

# %%
pd.read_hdf("test.h5", key="close").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %%
day_open = pd.read_hdf("./stock_data/day/day_open.h5")

# %%
day_open.to_hdf("test.h5", key="open")

# %%
pd.read_hdf("test.h5", key="close").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %% [markdown]
# ### 6.3 JSON

# %%
# orient="records" 数据以怎样的格式展示, lines=True  是否按行读取
sa = pd.read_json("Sarcasm_Headlines_Dataset.json", orient="records", lines=True)

# %%
sa
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
# orient="records" 数据以怎样的格式展示, lines=True  是否按行读取
sa.to_json("test.json", orient="records", lines=True)
